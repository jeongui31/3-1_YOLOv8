# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil

def apply_clahe_to_image(image_path, output_path, clip_limit=2.0, tile_grid_size=(4, 4)):
    # 이미지 읽기 (이미지를 RGB로 읽음)
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: 이미지 파일을 읽을 수 없습니다: {image_path}")
        return False

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # OpenCV의 기본 BGR을 RGB로 변환

    # RGB에서 YUV 색 공간으로 변환
    img_yuv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2YUV)

    # CLAHE 객체 생성 및 적용
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    img_yuv[:, :, 0] = clahe.apply(img_yuv[:, :, 0])  # Y 채널에 CLAHE 적용

    # 다시 RGB 색 공간으로 변환
    img_clahe_rgb = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)

    # CLAHE 적용 이미지를 파일로 저장
    success = cv2.imwrite(output_path, cv2.cvtColor(img_clahe_rgb, cv2.COLOR_RGB2BGR))
    if success:
        print(f"Saved processed image to: {output_path}")
    else:
        print(f"Error: Failed to save image to: {output_path}")
    return success

# 폴더 경로 설정
input_images_folder = '/home/under1/Detect/jeongui/coronal/crop/images/val'
input_labels_folder = '/home/under1/Detect/jeongui/coronal/crop/labels/val'
output_images_folder = '/home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE'
output_labels_folder = '/home/under1/Detect/jeongui/coronal/crop_CLAHE/labels/val_crop_CLAHE'

# 출력 폴더가 존재하지 않으면 생성
os.makedirs(output_images_folder, exist_ok=True)
os.makedirs(output_labels_folder, exist_ok=True)

# 이미지 파일에 CLAHE 적용
processed_images = []
for root, dirs, files in os.walk(input_images_folder):
    for filename in files:
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            input_image_path = os.path.join(root, filename)
            relative_path = os.path.relpath(input_image_path, input_images_folder)
            output_image_path = os.path.join(output_images_folder, relative_path)
            
            os.makedirs(os.path.dirname(output_image_path), exist_ok=True)
            
            # CLAHE 적용
            if apply_clahe_to_image(input_image_path, output_image_path):
                processed_images.append(output_image_path)

# 라벨 파일 복사
label_files = [f for f in os.listdir(input_labels_folder) if f.endswith('.txt')]

for label_file in label_files:
    input_label_path = os.path.join(input_labels_folder, label_file)
    output_label_path = os.path.join(output_labels_folder, label_file)
    shutil.copy(input_label_path, output_label_path)
    
# 결과 이미지 디스플레이 (예시로 첫 번째 이미지를 표시)
if processed_images:
    sample_image = processed_images[0]
    img_sample = cv2.imread(sample_image)
    img_sample_rgb = cv2.cvtColor(img_sample, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(10, 5))
    plt.imshow(img_sample_rgb)
    plt.axis('off')
    plt.title('Sample CLAHE Processed Image')
    plt.show()
else:
    print("Error: No processed images found in the output folder.")
# Out:
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/87.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/67 (2).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/71 (5).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/106.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/93 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/64.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/84 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/73 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70 (9).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/62 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/62 (15).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/66 (7).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/63.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/74 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/72 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/61 (7).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/83 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/93 (5).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/65 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/69 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/91 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/78 (2).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/82 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/85 (5).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/112.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/71 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/102 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/63 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/69 (8).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/62 (10).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/63 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/77 (5).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/61.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/77 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/100.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/92 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/92 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/77 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/66 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/98 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/85 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/87 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/72 (6).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/81.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/75 (5).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/84.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/69.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/66 (13).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70 (11).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70 (7).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70 (10).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/88.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/63 (4).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/79 (2).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/124.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/97 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/110.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/70 (2).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/74.jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/85 (2).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/79 (3).jpg
# Saved processed image to: /home/under1/Detect/jeongui/coronal/crop_CLAHE/images/val_crop_CLAHE/67 (3).jpg

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지 읽기 (이미지를 RGB로 읽음)
img = cv2.imread('./00095_188.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # OpenCV의 기본 BGR을 RGB로 변환

# RGB에서 YUV 색 공간으로 변환
img_yuv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2YUV)

# CLAHE 객체 생성 및 적용
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(4, 4)) #클립 한계를 3.0, 타일 그리드 크기를 (8,8)로 설정
img_yuv[:, :, 0] = clahe.apply(img_yuv[:, :, 0])  # Y 채널에 CLAHE 적용

# 다시 RGB 색 공간으로 변환
img_clahe_rgb = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)

# CLAHE 적용 이미지를 파일로 저장
cv2.imwrite('/mnt/data/image_clahe.png', cv2.cvtColor(img_clahe_rgb, cv2.COLOR_RGB2BGR))

# 이미지 디스플레이 (matplotlib 사용)
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Before')
plt.imshow(img_rgb)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('CLAHE')
plt.imshow(img_clahe_rgb)
plt.axis('off')

plt.show()
