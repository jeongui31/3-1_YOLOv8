# %%
import os
import shutil

def copy_images(input_folder, output_folder):
    # 이미지 파일 확장자 목록
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff']

    # input_folder에서 모든 파일을 탐색
    for filename in os.listdir(input_folder):
        # 파일의 전체 경로
        file_path = os.path.join(input_folder, filename)
        
        # 파일이 이미지 파일인지 확인
        if os.path.isfile(file_path) and any(filename.lower().endswith(ext) for ext in image_extensions):
            # output_folder로 파일 복사
            shutil.copy(file_path, output_folder)
            print(f"Copied {filename} to {output_folder}")

# 사용 예제
input_folder = '../super-resolution/images/train'
output_folder = './images/train'

# output_folder가 존재하지 않으면 생성
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

copy_images(input_folder, output_folder)
# Out:
# Copied 00110_162.jpg to ./images/train
# Copied 00071_259.jpg to ./images/train
# Copied 00059_122.jpg to ./images/train
# Copied 00177_125.jpg to ./images/train
# Copied 00133_247.jpg to ./images/train
# Copied 00192_191.jpg to ./images/train
# Copied 00128_243.jpg to ./images/train
# Copied 00123_241.jpg to ./images/train
# Copied 00104_168.jpg to ./images/train
# Copied 00138_217.jpg to ./images/train
# Copied 00165_176.jpg to ./images/train
# Copied 00060_72.jpg to ./images/train
# Copied 00074_249.jpg to ./images/train
# Copied 00159_189.jpg to ./images/train
# Copied 00177_221.jpg to ./images/train
# Copied 00137_264.jpg to ./images/train
# Copied 00143_236.jpg to ./images/train
# Copied 00095_201.jpg to ./images/train
# Copied 00159_133.jpg to ./images/train
# Copied 00066_259.jpg to ./images/train
# Copied 00177_241.jpg to ./images/train
# Copied 00156_196.jpg to ./images/train
# Copied 00132_130.jpg to ./images/train
# Copied 00071_240.jpg to ./images/train
# Copied 00178_158.jpg to ./images/train
# Copied 00060_71.jpg to ./images/train
# Copied 00056_147.jpg to ./images/train
# Copied 00100_119.jpg to ./images/train
# Copied 00142_144.jpg to ./images/train
# Copied 00090_112.jpg to ./images/train
# Copied 00110_147.jpg to ./images/train
# Copied 00151_162.jpg to ./images/train
# Copied 00122_90.jpg to ./images/train
# Copied 00056_92.jpg to ./images/train
# Copied 00061_146.jpg to ./images/train
# Copied 00158_256.jpg to ./images/train
# Copied 00107_118.jpg to ./images/train
# Copied 00191_143.jpg to ./images/train
# Copied 00058_122.jpg to ./images/train
# Copied 00159_171.jpg to ./images/train
# Copied 00192_244.jpg to ./images/train
# Copied 00058_141.jpg to ./images/train
# Copied 00059_141.jpg to ./images/train
# Copied 00147_115.jpg to ./images/train
# Copied 00078_219.jpg to ./images/train
# Copied 00172_91.jpg to ./images/train
# Copied 00144_278.jpg to ./images/train
# Copied 00169_243.jpg to ./images/train
# Copied 00058_179.jpg to ./images/train
# Copied 00151_145.jpg to ./images/train
# Copied 00143_254.jpg to ./images/train
# Copied 00100_136.jpg to ./images/train
# Copied 00054_164.jpg to ./images/train
# Copied 00072_119.jpg to ./images/train
# Copied 00184_145.jpg to ./images/train
# Copied 00187_118.jpg to ./images/train
# Copied 00108_102.jpg to ./images/train
# Copied 00072_99.jpg to ./images/train
# Copied 00160_270.jpg to ./images/train
# Copied 00187_170.jpg to ./images/train
# Copied 00201_121.jpg to ./images/train
# Copied 00077_186.jpg to ./images/train
# Copied 00194_243.jpg to ./images/train
# Copied 00061_184.jpg to ./images/train
# Copied 00195_208.jpg to ./images/train
# Copied 00061_108.jpg to ./images/train
# Copied 00133_228.jpg to ./images/train
# Copied 00171_126.jpg to ./images/train
# Copied 00183_161.jpg to ./images/train
# Copied 00100_102.jpg to ./images/train
# Copied 00063_197.jpg to ./images/train
# Copied 00183_109.jpg to ./images/train
# Copied 00156_116.jpg to ./images/train
# Copied 00183_144.jpg to ./images/train
# Copied 00201_102.jpg to ./images/train
# Copied 00059_103.jpg to ./images/train
# Copied 00158_239.jpg to ./images/train
# Copied 00183_195.jpg to ./images/train
# Copied 00124_114.jpg to ./images/train
# Copied 00169_260.jpg to ./images/train
# Copied 00097_87.jpg to ./images/train
# Copied 00151_128.jpg to ./images/train
# Copied 00165_158.jpg to ./images/train
# Copied 00178_104.jpg to ./images/train
# Copied 00087_149.jpg to ./images/train
# Copied 00167_213.jpg to ./images/train
# Copied 00178_175.jpg to ./images/train
# Copied 00151_195.jpg to ./images/train
# Copied 00071_278.jpg to ./images/train
# Copied 00156_132.jpg to ./images/train
# Copied 00162_122.jpg to ./images/train
# Copied 00066_221.jpg to ./images/train
# Copied 00124_168.jpg to ./images/train
# Copied 00063_217.jpg to ./images/train
# Copied 00194_259.jpg to ./images/train
# Copied 00074_209.jpg to ./images/train
# Copied 00097_106.jpg to ./images/train
# Copied 00056_129.jpg to ./images/train
# Copied 00096_260.jpg to ./images/train
# Copied 00185_271.jpg to ./images/train
# Copied 00066_240.jpg to ./images/train
# Copied 00106_195.jpg to ./images/train
# Copied 00185_252.jpg to ./images/train
# Copied 00064_101.jpg to ./images/train
# Copied 00154_210.jpg to ./images/train
# Copied 00154_248.jpg to ./images/train
# Copied 00150_252.jpg to ./images/train
# Copied 00166_206.jpg to ./images/train
# Copied 00143_272.jpg to ./images/train
# Copied 00059_84.jpg to ./images/train
# Copied 00142_89.jpg to ./images/train
# Copied 00166_189.jpg to ./images/train
# Copied 00071_221.jpg to ./images/train
# Copied 00077_166.jpg to ./images/train
# Copied 00159_207.jpg to ./images/train
# Copied 00128_277.jpg to ./images/train
# Copied 00138_289.jpg to ./images/train
# Copied 00109_85.jpg to ./images/train
# Copied 00071_183.jpg to ./images/train
# Copied 00095_243.jpg to ./images/train
# Copied 00191_106.jpg to ./images/train
# Copied 00105_151.jpg to ./images/train
# Copied 00072_196.jpg to ./images/train
# Copied 00176_127.jpg to ./images/train
# Copied 00077_226.jpg to ./images/train
# Copied 00104_150.jpg to ./images/train
# Copied 00098_247.jpg to ./images/train
# Copied 00097_162.jpg to ./images/train
# Copied 00147_134.jpg to ./images/train
# Copied 00156_180.jpg to ./images/train
# Copied 00187_135.jpg to ./images/train
# Copied 00147_170.jpg to ./images/train
# Copied 00123_277.jpg to ./images/train
# Copied 00056_239.jpg to ./images/train
# Copied 00121_175.jpg to ./images/train
# Copied 00058_102.jpg to ./images/train
# Copied 00146_142.jpg to ./images/train
# Copied 00128_260.jpg to ./images/train
# Copied 00193_208.jpg to ./images/train
# Copied 00066_278.jpg to ./images/train
# Copied 00130_273.jpg to ./images/train
# Copied 00105_113.jpg to ./images/train
# Copied 00072_138.jpg to ./images/train
# Copied 00177_280.jpg to ./images/train
# Copied 00144_260.jpg to ./images/train
# Copied 00169_208.jpg to ./images/train
# Copied 00193_172.jpg to ./images/train
# Copied 00157_115.jpg to ./images/train
# Copied 00187_153.jpg to ./images/train
# Copied 00132_164.jpg to ./images/train
# Copied 00120_245.jpg to ./images/train
# Copied 00074_269.jpg to ./images/train
# Copied 00146_195.jpg to ./images/train
# Copied 00147_152.jpg to ./images/train
# Copied 00136_121.jpg to ./images/train
# Copied 00166_259.jpg to ./images/train
# Copied 00176_145.jpg to ./images/train
# Copied 00104_132.jpg to ./images/train
# Copied 00183_126.jpg to ./images/train
# Copied 00178_140.jpg to ./images/train
# Copied 00072_80.jpg to ./images/train
# Copied 00105_132.jpg to ./images/train
# Copied 00116_231.jpg to ./images/train
# Copied 00158_272.jpg to ./images/train
# Copied 00183_178.jpg to ./images/train
# Copied 00120_215.jpg to ./images/train
# Copied 00178_122.jpg to ./images/train
# Copied 00177_260.jpg to ./images/train
# Copied 00095_181.jpg to ./images/train
# Copied 00078_258.jpg to ./images/train
# Copied 00109_104.jpg to ./images/train
# Copied 00056_110.jpg to ./images/train
# Copied 00110_131.jpg to ./images/train
# Copied 00096_240.jpg to ./images/train
# Copied 00136_138.jpg to ./images/train
# Copied 00124_96.jpg to ./images/train
# Copied 00151_211.jpg to ./images/train
# Copied 00132_95.jpg to ./images/train
# Copied 00142_163.jpg to ./images/train
# Copied 00169_225.jpg to ./images/train
# Copied 00142_107.jpg to ./images/train
# Copied 00186_207.jpg to ./images/train
# Copied 00054_145.jpg to ./images/train
# Copied 00146_160.jpg to ./images/train
# Copied 00156_148.jpg to ./images/train
# Copied 00166_241.jpg to ./images/train
# Copied 00191_124.jpg to ./images/train
# Copied 00107_101.jpg to ./images/train
# Copied 00061_127.jpg to ./images/train
# Copied 00123_259.jpg to ./images/train
# Copied 00095_222.jpg to ./images/train
# Copied 00165_122.jpg to ./images/train
# Copied 00117_200.jpg to ./images/train
# Copied 00100_153.jpg to ./images/train
# Copied 00078_278.jpg to ./images/train
# Copied 00120_230.jpg to ./images/train
# Copied 00087_130.jpg to ./images/train
# Copied 00165_193.jpg to ./images/train
# Copied 00122_108.jpg to ./images/train
# Copied 00123_223.jpg to ./images/train
# Copied 00100_170.jpg to ./images/train
# Copied 00077_206.jpg to ./images/train
# Copied 00142_126.jpg to ./images/train
# Copied 00132_112.jpg to ./images/train
# Copied 00154_267.jpg to ./images/train
# Copied 00177_145.jpg to ./images/train
# Copied 00104_185.jpg to ./images/train
# Copied 00193_190.jpg to ./images/train
# Copied 00192_262.jpg to ./images/train
# Copied 00121_157.jpg to ./images/train
# Copied 00106_253.jpg to ./images/train
# Copied 00159_152.jpg to ./images/train

# %%
#라벨 2배로 증가
import os
from shutil import copyfile

def duplicate_labels(input_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):  # Assuming label files have .txt extension
            label_path = os.path.join(input_folder, filename)
            
            # 원본 파일 복사
            copyfile(label_path, os.path.join(output_folder, filename))
            
            # noise가 붙은 파일명으로 복사
            noisy_filename = f"{os.path.splitext(filename)[0]}_sharp{os.path.splitext(filename)[1]}"
            copyfile(label_path, os.path.join(output_folder, noisy_filename))

# Usage example
input_folder = '../base/labels/train'
output_folder = './labels/train'
duplicate_labels(input_folder, output_folder)
